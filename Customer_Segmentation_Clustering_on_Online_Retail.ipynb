# %% [markdown]
# # **About Dataset -- Dataset From KAGGLE**
# # **Dataset --> Online Retail.xlsx(23.72 MB)**

# %% [markdown]
# ## **Problem statement:** Customer Segmentation/Clustering on Online Retail transnational data set.
#
# The Online Retail a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.The process of customer segmentation is based on the premise of finding differences among the customers’ behavior and patterns.
#
# ## **About the dataset:**
#
# InvoiceNo: A unique identifier for the invoice. An invoice number shared across rows means that those transactions were performed in a single invoice (multiple purchases).
#
# StockCode: Identifier for items contained in an invoice.
#
# Description: Textual description of each of the stock item.
#
# Quantity: The quantity of the item purchased.
#
# InvoiceDate: Date of purchase.
#
# UnitPrice: Value of each item.
#
# CustomerID: Identifier for customer making the purchase.
#
# Country: Country of customer.

# %% [markdown]
# # **Dataset Upload**

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-27d78df3-86aa-45d6-822b-aac2559ea479" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27d78df3-86aa-45d6-822b-aac2559ea479">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Read Dataset**

# %%
df = pd.read_excel('Online Retail.xlsx')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # **The first 5 columns of dataset**

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # **The last 5 columns of dataset**

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %% [markdown]
# #**Dataset Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# # **Dataset Description**

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %% [markdown]
# Here, we can see there is negative value in minimum Quantity and minium UnitPrice which can do misleading.

# %% [markdown]
# #**Total no. of Rows and Columns in Dataset**

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# #**Missing Data Checking**

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# Here we can see Description column has 1454 missing values and CustomerID has 135080 missing values.

# %% [markdown]
# #**Unique Value Count of Columns**

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %% [markdown]
# # **Unique Value Count of Categorical Columns**

# %%
print(df['Description'].nunique())
df['Description'].value_counts()
# Out:
# 4223
# WHITE HANGING HEART T-LIGHT HOLDER     2369
# REGENCY CAKESTAND 3 TIER               2200
# JUMBO BAG RED RETROSPOT                2159
# PARTY BUNTING                          1727
# LUNCH BAG RED RETROSPOT                1638
#                                        ...
# Missing                                   1
# historic computer difference?....se       1
# DUSTY PINK CHRISTMAS TREE 30CM            1
# WRAP BLUE RUSSIAN FOLKART                 1
# PINK BERTIE MOBILE PHONE CHARM            1
# Name: Description, Length: 4223, dtype: int64

# %%
df.Description.unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
print(df['Country'].nunique())
df['Country'].value_counts()
# Out:
# 38
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# **As CustomerID is mandatory for tracing the data, so, those data need to be  deleted from the dataframe which does not contain any CustomerID**

# %%
df = df[df['CustomerID'].notna()]

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# **Now, we do not have any missing data in the dataframe.**

# %%
df.describe().T
# Out:
#                count          mean          std      min       25%       50%  \
# Quantity    406829.0     12.061303   248.693370 -80995.0      2.00      5.00
# UnitPrice   406829.0      3.460471    69.315162      0.0      1.25      1.95
# CustomerID  406829.0  15287.690570  1713.600303  12346.0  13953.00  15152.00
#
#                  75%      max
# Quantity       12.00  80995.0
# UnitPrice       3.75  38970.0
# CustomerID  16791.00  18287.0

# %% [markdown]
# **Here, we can see there is minimum negative value in Quantity which can do misleading, so we should to only take the positive value and zero.**

# %%
df=df[(df.Quantity>=0)]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.describe().T
# Out:
#                count          mean          std      min       25%       50%  \
# Quantity    397924.0     13.021823   180.420210      1.0      2.00      6.00
# UnitPrice   397924.0      3.116174    22.096788      0.0      1.25      1.95
# CustomerID  397924.0  15294.315171  1713.169877  12346.0  13969.00  15159.00
#
#                  75%       max
# Quantity       12.00  80995.00
# UnitPrice       3.75   8142.75
# CustomerID  16795.00  18287.00

# %% [markdown]
# **Now we can see there is no negative value in description.**

# %% [markdown]
# # **Data preprocessing**

# %% [markdown]
# # **Label Encoder**
#
# ## **Using LabelEncoder to transform categorical variables(Country) into continuous variables.**

# %%
from sklearn.preprocessing import LabelEncoder

def label_encoding(column_name):
  label_encoder = LabelEncoder()
  df[column_name] = label_encoder.fit_transform(df[column_name])

# %%
label_encoding('Country')

# %%
df.Country.unique()
# Out:
# array([35, 13,  0, 23, 14, 24, 10, 32, 30, 25, 26, 18,  3, 21, 19, 16,  6,
#         9,  7, 31, 12,  1, 15, 29, 20, 34, 17, 28,  8,  5, 36,  4, 33, 11,
#         2, 22, 27])

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID  Country
# 0 2010-12-01 08:26:00       2.55     17850.0       35
# 1 2010-12-01 08:26:00       3.39     17850.0       35
# ...

# %% [markdown]
# # **Correlation**

# %%
cor = df.corr()
cor
# Out:
#             Quantity  UnitPrice  CustomerID   Country
# Quantity    1.000000  -0.004561   -0.006411 -0.012796
# UnitPrice  -0.004561   1.000000   -0.010863 -0.015720
# CustomerID -0.006411  -0.010863    1.000000  0.387672
# Country    -0.012796  -0.015720    0.387672  1.000000

# %% [markdown]
# # **Heatmap**

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(cor, annot = True, cmap = 'Pastel1_r')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# There isn't much correlation in the data.
#
# Most of the correlation are negative
#
# Only CustomerID and Country has a positive but weak correlation.

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# **For EDA purpose we will be cosidering only the correlation columns .**

# %%
cols=['Quantity','UnitPrice', 'Country', 'CustomerID']


df0 =df.head(500)

sns.pairplot(df0[cols])

# %%
sns.heatmap(df[cols].corr(), annot = True)
plt.title('Heatmap for the Data')
plt.show()

# %% [markdown]
# **No strong correlation is visible.**

# %%
print(cols)
sns.pairplot(df0[cols], kind="reg")
# Out:
# ['Quantity', 'UnitPrice', 'Country', 'CustomerID']

# %% [markdown]
# CustomerID No. around 16000, they shows a liner correlation with Quantity, seems they are stable customer. But a deline is showing among them in terms of UnitPrice.

# %%
sns.pairplot(df0[cols], hue='Country', kind='reg')

# %% [markdown]
# Here, 35 is UK.
#
# We can see compare to other countries, customer from the UK has more corrleation with Quantity and UnitPrice. It seems Uk customers buy lot than other countries.

# %% [markdown]
# # **Segmentation / Clustering using K-means**

# %% [markdown]
# # **Principal Component Analysis (PCA)**

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
points = pca.fit_transform(df[cols])

# %%
df['PC_1'] = points[:,0]
df['PC_2'] = points[:,1]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID  Country         PC_1  \
# ...

# %%
sum(pca.explained_variance_ratio_)*100
# Out:
# 99.98226202332697

# %%
plt.figure(1 , figsize = (10,10))
sns.scatterplot(x='PC_1', y='PC_2', data=df, s=50)

# %% [markdown]
# # **The Elbow Method**

# %%
# Let's find right fit for K
from sklearn.cluster import KMeans
import numpy as np

# Within Cluster Sum of Squared Errors (WCSS) 
wcss = []
max_range = 16
for i in range(1, max_range):
    km = KMeans(n_clusters = i, init = 'k-means++')
    km.fit(df[cols])
    wcss.append(km.inertia_)
    
plt.figure(1 , figsize = (7, 4))
plt.plot(np.arange(1 , max_range) , wcss , 'o')
plt.plot(np.arange(1 , max_range) , wcss , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# **Here we see the Elbow Method  got the last breakage exactly at 3. After 3 it has a continuous line. So, the no. of cluster should be 3.**

# %% [markdown]
# # **K-Means Algorithm**

# %%
algorithm = KMeans(n_clusters = 3) 
algorithm.fit(df[cols])
grp = algorithm.labels_
df['group'] = grp
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID  Country         PC_1  \
# ...

# %% [markdown]
# #**Analysing the 3 clusters with the help of Scatter Plot.**

# %%
plt.figure(1 , figsize = (8, 6))
sns.scatterplot(x='PC_1', y='PC_2', hue='group', data=df, s=100, palette="Set1")

# %% [markdown]
# **Here we see 3 types of clusters.**

# %%
grp0 = df[df["group"]==0].copy()
grp1 = df[df["group"]==1].copy()
grp2 = df[df["group"]==2].copy()

# %% [markdown]
# # **Description of each cluster**

# %%
grp0[cols].describe().T
# Out:
#                count          mean         std      min       25%       50%  \
# Quantity    139090.0     12.100223   38.482593      1.0      2.00      5.00
# UnitPrice   139090.0      3.068548   25.770900      0.0      1.25      1.95
# Country     139090.0     33.571191    5.629625      5.0     35.00     35.00
# CustomerID  139090.0  15144.571536  561.757021  14208.0  14649.00  15050.00
#
#                  75%       max
# Quantity       12.00   3186.00
# UnitPrice       3.75   8142.75
# Country        35.00     36.00
# CustomerID  15615.00  16208.00

# %% [markdown]
# Most of the parameters description of group grp0 are different from the real data set parameters description. But some similarites are also visible. Such as in Quantity and UnitPrice in terms of min, 25%, 50%, 75%.

# %%
grp1[cols].describe().T
# Out:
#                count          mean         std      min       25%       50%  \
# Quantity    136007.0     12.453337  224.537229      1.0      2.00      4.00
# UnitPrice   136007.0      2.848281    9.005632      0.0      1.25      1.79
# Country     136007.0     34.942782    1.117374      0.0     35.00     35.00
# CustomerID  136007.0  17273.794099  579.018594  16209.0  16767.00  17321.00
#
#                  75%      max
# Quantity       12.00  80995.0
# UnitPrice       3.75   2033.1
# Country        35.00     36.0
# CustomerID  17799.00  18287.0

# %% [markdown]
# Most of the parameters description of group grp1 are somehow similar to the real data set parameters description. But dissimilarites are also visible. Such as in Quantity and UnitPrice in terms of Count, mean and std.

# %%
grp2[cols].describe().T
# Out:
#                count          mean         std      min       25%       50%  \
# Quantity    122827.0     14.694937  218.974337      1.0      3.00      6.00
# UnitPrice   122827.0      3.466746   27.198739      0.0      1.25      1.95
# Country     122827.0     29.704552    9.660600      0.0     30.00     35.00
# CustomerID  122827.0  13271.998022  570.816038  12346.0  12748.00  13230.00
#
#                  75%       max
# Quantity       12.00  74215.00
# UnitPrice       3.75   4161.06
# Country        35.00     36.00
# CustomerID  13787.00  14206.00

# %% [markdown]
# Here, we can see, it is the dominating group of cluster, because the minimum parameter of grp2 is exactly same to minimum parameter of real data set. But the max, 25%, 75% value of Quantity, 25%, 50%, 75%, max, min value of UnitPrice is almost close to real data set but stil slightly different from it. Also group grp2 has dissimilarites with the real dataset in terms of count, mean and std.

# %%
df[cols].describe().T
# Out:
#                count          mean          std      min       25%       50%  \
# Quantity    397924.0     13.021823   180.420210      1.0      2.00      6.00
# UnitPrice   397924.0      3.116174    22.096788      0.0      1.25      1.95
# Country     397924.0     32.846476     6.711504      0.0     35.00     35.00
# CustomerID  397924.0  15294.315171  1713.169877  12346.0  13969.00  15159.00
#
#                  75%       max
# Quantity       12.00  80995.00
# UnitPrice       3.75   8142.75
# Country        35.00     36.00
# CustomerID  16795.00  18287.00

# %%
sns.pairplot(grp2[cols], kind="reg")

# %%
grp0[cols].corr()
# Out:
#             Quantity  UnitPrice   Country  CustomerID
# Quantity    1.000000  -0.016418 -0.078297   -0.008291
# UnitPrice  -0.016418   1.000000 -0.012080    0.002952
# Country    -0.078297  -0.012080  1.000000    0.128872
# CustomerID -0.008291   0.002952  0.128872    1.000000

# %% [markdown]
# In grp0 the correalation is visible between CustomerID with UnitPrice and Country, which is positive and very weak correlation.

# %%
grp1[cols].corr()
# Out:
#             Quantity  UnitPrice   Country  CustomerID
# Quantity    1.000000  -0.006794 -0.003973   -0.003137
# UnitPrice  -0.006794   1.000000 -0.011541    0.003416
# Country    -0.003973  -0.011541  1.000000   -0.010821
# CustomerID -0.003137   0.003416 -0.010821    1.000000

# %% [markdown]
# In grp1 the correalation is visible between CustomerID and UnitPrice, which is positive and very weak correlation.

# %%
grp2[cols].corr()
# Out:
#             Quantity  UnitPrice   Country  CustomerID
# Quantity    1.000000  -0.004376 -0.010662   -0.010333
# UnitPrice  -0.004376   1.000000 -0.013994   -0.007232
# Country    -0.010662  -0.013994  1.000000    0.573239
# CustomerID -0.010333  -0.007232  0.573239    1.000000

# %% [markdown]
# In grp2 the correalation is visible between CustomerID and Country, which is positive and moderate or medium correlation.

# %% [markdown]
# ### ***From the analysis it can be concluded that the customers belongs to grp2 group of cluster is different from other 2 group of clusters.***
